# %%
import pandas as pd
from glob import glob

# %%
file = "/home/iagonmic/data_science/dialogic_accounting_pibic/data/processed/amostra_final_classificada.xlsx"

# %%
df = pd.read_excel(file)

# %%
df[df['Comments per post'] <= 101]['Comments per post'].sum()
# Out:
# np.int64(79521)

# %%
df.describe(percentiles=[0.90])
# Out:
#              index                           Date  \
# count  4468.000000                           4468
# mean    770.977171  2024-07-08 13:27:33.088182784
# min       0.000000            2024-01-01 10:00:50
# 50%     627.500000            2024-07-08 19:49:27
# 90%    1601.000000            2024-11-30 12:19:51
# max    3549.000000            2025-01-01 02:29:40
# std     646.944543                            NaN
#
#        Reactions, Comments & Shares  Likes per post  Comments per post  \
# count                   4468.000000     4468.000000        4468.000000
# mean                     770.849373      722.905998          47.943375
# min                        0.000000        0.000000           0.000000
# 50%                      279.000000      264.500000          14.000000
# 90%                     1497.300000     1353.900000         101.000000
# max                   100070.000000    88883.000000       11187.000000
# ...

# %%
df = df[df['Comments per post'] <= 101]

# %%
df.describe()
# Out:
#              index                           Date  \
# count  4024.000000                           4024
# mean    792.345427  2024-07-09 11:27:37.603876608
# min       0.000000            2024-01-01 10:00:50
# 25%     303.750000  2024-04-10 11:31:30.750000128
# 50%     654.500000            2024-07-11 12:14:37
# 75%    1078.250000     2024-10-07 21:50:37.500000
# max    3549.000000            2025-01-01 02:29:40
# std     663.044707                            NaN
#
#        Reactions, Comments & Shares  Likes per post  Comments per post  \
# count                   4024.000000     4024.000000         4024.00000
# mean                     401.201541      381.439861           19.76168
# min                        0.000000        0.000000            0.00000
# 25%                      114.000000      108.000000            4.00000
# 50%                      243.500000      227.000000           11.00000
# 75%                      479.000000      447.250000           28.00000
# ...

# %%
df.to_excel('/home/iagonmic/data_science/dialogic_accounting_pibic/data/processed/amostra_final_101_comentarios.xlsx', index=False)
